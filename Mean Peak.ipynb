# %%
import pandas as pd
df = pd.read_csv("TYPICAL_HOURLY_VOLUME_DATA.csv")
lst =[]
for i in range(len(df)):
    if "SCHOOL TERM/NORMAL" not in df["PERIOD_TYPE"][i]:
        lst.append(i)
morning_mean= []
afternoon_mean=[]
data = df.drop(labels=lst, axis=0)
data = data.reset_index()
data = data.drop(labels=["index",'0:00','1:00','2:00','3:00','4:00','5:00','6:00','7:00','10:00','11:00','12:00','13:00','14:00','19:00','20:00','21:00','22:00','23:00'], axis=1)
sums1 = 0
sums2 = 0
for index, row in data.iterrows():
    sums1 = row[7]+row[8]
    sums2 = row[9]+row[10]+row[11]+row[12]
    morning_mean.append(sums1/2)
    afternoon_mean.append(sums2/4)
    sums1 = 0
    sums2 = 0
avg = []
m = 0
for i in range(len(morning_mean)):
    m = (morning_mean[i] + afternoon_mean[i])/2
    avg.append(m)
    m = 0
data["AVERAGE"] = avg
data["MORNING_MEAN"] = morning_mean
data["AFTERNOON_MEAN"] = afternoon_mean
data["AVERAGE"] = avg
data = data.drop(labels=['DOW','8:00','9:00','15:00','16:00','17:00','18:00'], axis=1)

data = data.groupby(["HMGNS_FLOW_ID","HMGNS_LNK_ID","HMGNS_LNK_DESC","FLOW"]).mean().sort_values(by='AVERAGE', ascending=False)
data.to_csv("mean_volume1.csv")

display(data)
# Out:
#                                                                                                     AVERAGE  \
# HMGNS_FLOW_ID HMGNS_LNK_ID HMGNS_LNK_DESC                                     FLOW
# 15964         2157          WEST GATE FREEWAY btwn ramps at Western link      WEST BOUND        7796.196429
# 14538         2163          WEST GATE FREEWAY E BD BTWN $$ & $$               EAST BOUND        7540.428571
# 7472          8417          MONASH FREEWAY btwn Huntingdale Rd and Forster Rd WEST BOUND        6521.232143
# 371           8417          MONASH FREEWAY btwn Huntingdale Rd and Forster Rd EAST BOUND        6500.660714
# 5             8726          MONASH FREEWAY btwn Blackburn Rd & Forster Rd     EAST BOUND        6411.553571
# ...                                                                                                     ...
# 1284          1659          SNOWY RIVER ROAD btwn GELANTIPY ROAD & SNOWY R... NORTH EAST BOUND     0.714286
# 8390          1659          SNOWY RIVER ROAD btwn GELANTIPY ROAD & SNOWY R... SOUTH WEST BOUND     0.642857
# 8933          1602          TATONG-TOLMIE ROAD btwn BENALLA-TATONG ROAD & ... NORTH WEST BOUND     0.500000
# 8585          1603          MURRUNGOWER ROAD btwn PRINCES HIGHWAY EAST & G... SOUTH WEST BOUND     0.357143
# 1857          1603          MURRUNGOWER ROAD btwn PRINCES HIGHWAY EAST & G... NORTH EAST BOUND     0.285714
#
#                                                                                                 MORNING_MEAN  \
# HMGNS_FLOW_ID HMGNS_LNK_ID HMGNS_LNK_DESC                                     FLOW
# 15964         2157          WEST GATE FREEWAY btwn ramps at Western link      WEST BOUND         6361.571429
# 14538         2163          WEST GATE FREEWAY E BD BTWN $$ & $$               EAST BOUND         7525.571429
# 7472          8417          MONASH FREEWAY btwn Huntingdale Rd and Forster Rd WEST BOUND         6690.857143
# 371           8417          MONASH FREEWAY btwn Huntingdale Rd and Forster Rd EAST BOUND         5610.428571
# 5             8726          MONASH FREEWAY btwn Blackburn Rd & Forster Rd     EAST BOUND         5273.000000
# ...                                                                                                      ...
# 1284          1659          SNOWY RIVER ROAD btwn GELANTIPY ROAD & SNOWY R... NORTH EAST BOUND      0.785714
# 8390          1659          SNOWY RIVER ROAD btwn GELANTIPY ROAD & SNOWY R... SOUTH WEST BOUND      0.357143
# 8933          1602          TATONG-TOLMIE ROAD btwn BENALLA-TATONG ROAD & ... NORTH WEST BOUND      0.571429
# 8585          1603          MURRUNGOWER ROAD btwn PRINCES HIGHWAY EAST & G... SOUTH WEST BOUND      0.000000
# 1857          1603          MURRUNGOWER ROAD btwn PRINCES HIGHWAY EAST & G... NORTH EAST BOUND      0.571429
#
#                                                                                                 AFTERNOON_MEAN
# HMGNS_FLOW_ID HMGNS_LNK_ID HMGNS_LNK_DESC                                     FLOW
# 15964         2157          WEST GATE FREEWAY btwn ramps at Western link      WEST BOUND           9230.821429
# 14538         2163          WEST GATE FREEWAY E BD BTWN $$ & $$               EAST BOUND           7555.285714
# 7472          8417          MONASH FREEWAY btwn Huntingdale Rd and Forster Rd WEST BOUND           6351.607143
# 371           8417          MONASH FREEWAY btwn Huntingdale Rd and Forster Rd EAST BOUND           7390.892857
# 5             8726          MONASH FREEWAY btwn Blackburn Rd & Forster Rd     EAST BOUND           7550.107143
# ...                                                                                                        ...
# 1284          1659          SNOWY RIVER ROAD btwn GELANTIPY ROAD & SNOWY R... NORTH EAST BOUND        0.642857
# 8390          1659          SNOWY RIVER ROAD btwn GELANTIPY ROAD & SNOWY R... SOUTH WEST BOUND        0.928571
# 8933          1602          TATONG-TOLMIE ROAD btwn BENALLA-TATONG ROAD & ... NORTH WEST BOUND        0.428571
# 8585          1603          MURRUNGOWER ROAD btwn PRINCES HIGHWAY EAST & G... SOUTH WEST BOUND        0.714286
# 1857          1603          MURRUNGOWER ROAD btwn PRINCES HIGHWAY EAST & G... NORTH EAST BOUND        0.000000
#
# [10722 rows x 3 columns]

# %%
from scipy import stats
import numpy as np
stats.spearmanr([1,2,3,4,5], [5,6,7,8,7])

np.random.seed(1234321)
x2n = np.random.randn(100, 2)
y2n = np.random.randn(100, 2)
stats.spearmanr(x2n)

stats.spearmanr(x2n[:,0], x2n[:,1])

rho, pval = stats.spearmanr(x2n, y2n)
rho




pval




rho, pval = stats.spearmanr(x2n.T, y2n.T, axis=1)
rho




stats.spearmanr(x2n, y2n, axis=None)

stats.spearmanr(x2n.ravel(), y2n.ravel())
# Out:
# SpearmanrResult(correlation=0.10816770419260482, pvalue=0.12735621880273648)

# %%
import matplotlib.pyplot as mp
import pandas as pd
import seaborn as sb

print(data.corr())
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-3-09533712b77c> in <module>
#       3 import seaborn as sb
#       4
# ----> 5 print(data.corr())
#
# NameError: name 'data' is not defined
